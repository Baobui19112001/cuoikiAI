# %% [markdown]
# <a href="https://colab.research.google.com/github/Baobui19112001/cuoikiAI/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
import pylab as pl
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import (RandomForestClassifier, ExtraTreesClassifier,
                              AdaBoostClassifier)
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Any results you write to the current directory are saved as output.
import os
sounds = os.listdir("/content/drive/MyDrive/cuoikiAI/chomeo/AI/train/")
print(os.listdir("/content/drive/MyDrive/cuoikiAI/chomeo/AI/train/"))
import warnings
warnings.filterwarnings("ignore")
# Out:
# ['Lion', 'Dog', 'Pig', 'Cow', 'Frog', 'Bird', 'Horse', 'Cat', 'Chicken', 'Sheep']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob
import ntpath
# List the wav files
ROOT_DIR_TEST = glob.glob('/content/drive/MyDrive/cuoikiAI/chomeo/AI/test')[0]
ROOT_DIR_TRAIN = glob.glob('/content/drive/MyDrive/cuoikiAI/chomeo/AI/train')[0]
X_path = glob.glob(ROOT_DIR_TEST + "/Dog/*") 
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Cat/*")
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Bird/*")
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Chicken/*")
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Cow/*")
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Frog/*")
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Horse/*")
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Lion/*")
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Pig/*")
X_path = X_path + glob.glob(ROOT_DIR_TEST + "/Sheep/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Dog/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Cat/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Bird/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Chicken/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Cow/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Frog/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Lion/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Horse/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Pig/*")
X_path = X_path + glob.glob(ROOT_DIR_TRAIN + "/Sheep/*")
print (len(X_path))
# Out:
# 485

# %%
y = np.empty((0, 1, ))
for f in X_path:
    if 'cat' in ntpath.basename(f):
        resp = np.array([0])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp))
    if 'dog' in ntpath.basename(f):
        resp = np.array([1])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp))
    if 'bird' in ntpath.basename(f):
        resp = np.array([2])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp)) 
    if 'chicken' in ntpath.basename(f):
        resp = np.array([3])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp))
    if 'frog' in ntpath.basename(f):
        resp = np.array([4])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp))
    if 'cow' in ntpath.basename(f):
        resp = np.array([5])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp))     
    if 'lion' in ntpath.basename(f):
        resp = np.array([6])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp)) 
    if 'horse' in ntpath.basename(f):
        resp = np.array([7])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp)) 
    if 'pig' in ntpath.basename(f):
        resp = np.array([8])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp))
    if 'sheep' in ntpath.basename(f):
        resp = np.array([9])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp)) 
print (y.shape)
# Out:
# (485, 1)

# %%
# Split train and test
X_train, X_test, y_train, y_test = train_test_split(X_path, y, test_size=0.33)
print("in X, there is {} cats and {} dogs".format(len(y) - sum(y), sum(y)))
print("in X_train, there is {} cats and {} dogs".format(len(y_train) - sum(y_train), sum(y_train)))
print("in X_test, there is {} cats and {} dogs".format(len(y_test) - sum(y_test), sum(y_test)))
print("len(y_train)",len(y_train))
print("len(y_test)",len(y_test))
print(y_test.shape)
print(y_train.shape)
# Out:
# in X, there is [-859.] cats and [1344.] dogs
# in X_train, there is [-558.] cats and [882.] dogs
# in X_test, there is [-301.] cats and [462.] dogs
# len(y_train) 324
# len(y_test) 161
# (161, 1)
# (324, 1)

# %%
def read_wav_files(wav_files):
    '''Returns a list of audio waves
    Params:
        wav_files: List of .wav paths
    
    Returns:
        List of audio signals
    '''
    if not isinstance(wav_files, list):
        wav_files = [wav_files]
    return [sci_wav.read(f)[1] for f in wav_files]

# %%
def librosa_read_wav_files(wav_files):
    if not isinstance(wav_files, list):
        wav_files = [wav_files]
    return [librosa.load(f)[0] for f in wav_files]

# %%
import librosa
wav_rate = librosa.load(X_train[0])[1]
X_train = librosa_read_wav_files(X_train)
X_test  = librosa_read_wav_files(X_test)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(16,7))
axs[0][0].plot(X_train[0])
axs[0][1].plot(X_train[1])
axs[1][0].plot(X_train[2])
axs[1][1].plot(X_train[3])
plt.show()

# %%
# function to extract all the features needed for the classification
def extract_features(audio_samples, sample_rate):
    extracted_features = np.empty((0, 41, ))
    if not isinstance(audio_samples, list):
        audio_samples = [audio_samples]
        
    for sample in audio_samples:
        # calculate the zero-crossing feature
        zero_cross_feat = librosa.feature.zero_crossing_rate(sample).mean()
        
        # calculate the mfccs features
        mfccs = librosa.feature.mfcc(y=sample, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)

        # add zero crossing feature to the feature list
        mfccsscaled = np.append(mfccsscaled, zero_cross_feat)
        mfccsscaled = mfccsscaled.reshape(1, 41, )
        extracted_features = np.vstack((extracted_features, mfccsscaled))

    # return the extracted features
    return extracted_features

# %%
features = ((extract_features(X_train[0], wav_rate)))
print (len(features))
print (features.shape)
plt.plot(features[0])
# Out:
# 1
# (1, 41)

# %%
X_train_features = extract_features(X_train, wav_rate)
X_test_features  = extract_features(X_test, wav_rate)
print("Image array shape: ", X_train_features.shape)
print("Image array shape: ", X_test_features.shape)
print("Label array shape: ", y_train.shape)
print("Label array shape: ", y_test.shape)
# Out:
# Image array shape:  (324, 41)
# Image array shape:  (161, 41)
# Label array shape:  (324, 1)
# Label array shape:  (161, 1)

# %%
from keras import layers
from keras import models
from keras import optimizers
from keras import losses
from keras.callbacks import ModelCheckpoint,EarlyStopping

# %%
from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(y_train)
test_labels = to_categorical(y_test)

# %%
model = models.Sequential()

model.add(layers.Dense(100, activation = 'relu', input_shape = (41, )))
model.add(layers.Dense(50, activation = 'relu'))
model.add(layers.Dense(10, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4200
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 9,760
# Trainable params: 9,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Choose the parameters to train the neural network
best_model_weights = './base.model'
checkpoint = ModelCheckpoint(
                              best_model_weights,
                              monitor='val_acc',
                              verbose=1,
                              save_best_only=True,
                              mode='min',
                              save_weights_only=False,
                              period=1
                            )

callbacks = [checkpoint]

model.compile(optimizer='adam',
              loss=losses.categorical_crossentropy,
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(
    X_train_features,
    train_labels,
    validation_data=(X_test_features,test_labels),
    epochs = 100, 
    verbose = 1,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
#  1/11 [=>............................] - ETA: 6s - loss: 24.6884 - accuracy: 0.0000e+00WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 1s 25ms/step - loss: 15.3060 - accuracy: 0.1975 - val_loss: 7.4725 - val_accuracy: 0.2547
# Epoch 2/100
#  1/11 [=>............................] - ETA: 0s - loss: 8.6078 - accuracy: 0.2812WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 6.7180 - accuracy: 0.3704 - val_loss: 4.8788 - val_accuracy: 0.4845
# Epoch 3/100
#  1/11 [=>............................] - ETA: 0s - loss: 5.6512 - accuracy: 0.4062WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 3.
100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0876 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0976 - accuracy: 0.9846 - val_loss: 1.1540 - val_accuracy: 0.7826
# Epoch 33/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.1226 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0960 - accuracy: 0.9815 - val_loss: 1.1634 - val_accuracy: 0.7888
# Epoch 34/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.1114 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0910 - accuracy: 0.9846 - val_loss: 1.1591 - val_accuracy: 0.7888
# Epoch 35/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0757 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0902 - accuracy: 0.9784 - val_loss: 1.2195 - val_accuracy: 0.7826
# Epoch 36/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0318 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0797 - accuracy: 0.9877 - val_loss: 1.1962 - val_accuracy: 0.7826
# Epoch 37/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0683 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.9846 - val_loss: 1.1778 - val_accuracy: 0.8012
# Epoch 38/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0583 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0690 - accuracy: 0.9877 - val_loss: 1.1965 - val_accuracy: 0.7888
# Epoch 39/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0575 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0614 - accuracy: 0.9938 - val_loss: 1.2053 - val_accuracy: 0.7950
# Epoch 40/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0459 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0601 - accuracy: 0.9938 - val_loss: 1.2181 - val_accuracy: 0.7950
# Epoch 41/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0344 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0787 - accuracy: 0.9846 - val_loss: 1.2069 - val_accuracy: 0.7826
# Epoch 42/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0717 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0624 - accuracy: 0.9969 - val_loss: 1.2226 - val_accuracy: 0.8075
# Epoch 43/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0724 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0698 - accuracy: 0.9907 - val_loss: 1.2435 - val_accuracy: 0.7888
# Epoch 44/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0542 - accuracy: 0.9938 - val_loss: 1.2169 - val_accuracy: 0.8075
# Epoch 45/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0894 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0614 - accuracy: 0.9938 - val_loss: 1.3324 - val_accuracy: 0.7826
# Epoch 46/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0559 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0573 - accuracy: 0.9938 - val_loss: 1.2362 - val_accuracy: 0.7888
# Epoch 47/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0222 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0508 - accuracy: 0.9938 - val_loss: 1.2357 - val_accuracy: 0.8012
# Epoch 48/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0386 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0419 - accuracy: 1.0000 - val_loss: 1.2146 - val_accuracy: 0.8012
# Epoch 49/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0275 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 1.2244 - val_accuracy: 0.7950
# Epoch 50/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0269 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0380 - accuracy: 0.9969 - val_loss: 1.2408 - val_accuracy: 0.7950
# Epoch 51/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0664 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0439 - accuracy: 0.9969 - val_loss: 1.2637 - val_accuracy: 0.7888
# Epoch 52/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0359 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 1.2347 - val_accuracy: 0.7888
# Epoch 53/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0599 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 1.2586 - val_accuracy: 0.8012
# Epoch 54/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0471 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 1.2465 - val_accuracy: 0.7950
# Epoch 55/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0591 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0340 - accuracy: 0.9969 - val_loss: 1.2745 - val_accuracy: 0.7950
# Epoch 56/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0316 - accuracy: 0.9969 - val_loss: 1.2766 - val_accuracy: 0.8012
# Epoch 57/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0139 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.2848 - val_accuracy: 0.7950
# Epoch 58/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0248 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 1.2765 - val_accuracy: 0.7950
# Epoch 59/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0255 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 1.2857 - val_accuracy: 0.7950
# Epoch 60/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0204 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 1.2784 - val_accuracy: 0.8012
# Epoch 61/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0126 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 1.2898 - val_accuracy: 0.7950
# Epoch 62/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 1.3027 - val_accuracy: 0.7888
# Epoch 63/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0285 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 1.2946 - val_accuracy: 0.7950
# Epoch 64/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0356 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 1.2844 - val_accuracy: 0.7888
# Epoch 65/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0234 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 1.2968 - val_accuracy: 0.7888
# Epoch 66/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0282 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 1.3063 - val_accuracy: 0.7888
# Epoch 67/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0153 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 1.3155 - val_accuracy: 0.7950
# Epoch 68/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 1.3073 - val_accuracy: 0.7950
# Epoch 69/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0151 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 1.3362 - val_accuracy: 0.7888
# Epoch 70/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0240 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 0.9969 - val_loss: 1.3177 - val_accuracy: 0.8012
# Epoch 71/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0131 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0266 - accuracy: 0.9969 - val_loss: 1.3261 - val_accuracy: 0.8137
# Epoch 72/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0192 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0413 - accuracy: 0.9907 - val_loss: 1.4875 - val_accuracy: 0.7826
# Epoch 73/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.1683 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0483 - accuracy: 0.9846 - val_loss: 1.3388 - val_accuracy: 0.7888
# Epoch 74/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0576 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0410 - accuracy: 0.9938 - val_loss: 1.3837 - val_accuracy: 0.7826
# Epoch 75/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0219 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 1.4460 - val_accuracy: 0.7826
# Epoch 76/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0271 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 1.4000 - val_accuracy: 0.7888
# Epoch 77/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0159 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 1.3665 - val_accuracy: 0.7888
# Epoch 78/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 1.3613 - val_accuracy: 0.7950
# Epoch 79/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0253 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 1.3864 - val_accuracy: 0.7826
# Epoch 80/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0094 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.3700 - val_accuracy: 0.8012
# Epoch 81/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 1.3757 - val_accuracy: 0.8075
# Epoch 82/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.4123 - val_accuracy: 0.7888
# Epoch 83/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 1.4196 - val_accuracy: 0.7888
# Epoch 84/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0167 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.4055 - val_accuracy: 0.7950
# Epoch 85/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.3988 - val_accuracy: 0.8012
# Epoch 86/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.4057 - val_accuracy: 0.7950
# Epoch 87/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0084 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.3980 - val_accuracy: 0.7950
# Epoch 88/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.4012 - val_accuracy: 0.7888
# Epoch 89/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.4014 - val_accuracy: 0.7950
# Epoch 90/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.3997 - val_accuracy: 0.7888
# Epoch 91/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.4028 - val_accuracy: 0.8012
# Epoch 92/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.3773 - val_accuracy: 0.8012
# Epoch 93/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.3795 - val_accuracy: 0.7950
# Epoch 94/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.3941 - val_accuracy: 0.7888
# Epoch 95/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.4019 - val_accuracy: 0.7950
# Epoch 96/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.4005 - val_accuracy: 0.7888
# Epoch 97/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0108 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.4166 - val_accuracy: 0.7950
# Epoch 98/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.4237 - val_accuracy: 0.7950
# Epoch 99/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.4126 - val_accuracy: 0.7888
# Epoch 100/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.4237 - val_accuracy: 0.7888

# %%
# list all data in history
print(history.history.keys())

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'b', label = "training accuracy")
plt.plot(epochs, val_acc, 'r', label = "validation accuracy")
plt.title('Training and validation accuracy')
plt.legend()

plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import IPython.display as ipd

# %%
nr_to_predict = 41
pred = model.predict(X_test_features[nr_to_predict].reshape(1, 41,))
if (y_test[nr_to_predict] == 0):
    print ("Day la con meo")
if (y_test[nr_to_predict] == 1):
    print ("Day la con cho")
if (y_test[nr_to_predict] == 2):
  print ("Day la con chim")
if (y_test[nr_to_predict] == 3):
  print ("Day la con ga")
if (y_test[nr_to_predict] == 4):
    print ("Day la con ech")
if (y_test[nr_to_predict] == 5):
    print ("Day la con bo")
if (y_test[nr_to_predict] == 6):
    print ("Day la con su tu")
if (y_test[nr_to_predict] == 7):
    print ("Day la con ngua")
if (y_test[nr_to_predict] == 8):
    print ("Day la con heo")
if (y_test[nr_to_predict] == 9):
    print ("Day la con cuu")
plt.plot(X_test_features[nr_to_predict])
ipd.Audio(X_test[nr_to_predict],  rate=wav_rate)
# Out:
# Day la con meo
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
nr_to_predict = 103
pred = model.predict(X_test_features[nr_to_predict].reshape(1, 41,))
if (y_test[nr_to_predict] == 0):
    print ("Day la con meo")
if (y_test[nr_to_predict] == 1):
    print ("Day la con cho")
if (y_test[nr_to_predict] == 2):
  print ("Day la con chim")
if (y_test[nr_to_predict] == 3):
  print ("Day la con ga")
if (y_test[nr_to_predict] == 4):
    print ("Day la con ech")
if (y_test[nr_to_predict] == 5):
    print ("Day la con bo")
if (y_test[nr_to_predict] == 6):
    print ("Day la con su tu")
if (y_test[nr_to_predict] == 7):
    print ("Day la con ngua")
if (y_test[nr_to_predict] == 8):
    print ("Day la con heo")
if (y_test[nr_to_predict] == 9):
    print ("Day la con cuu")
plt.plot(X_test_features[nr_to_predict])
ipd.Audio(X_test[nr_to_predict],  rate=wav_rate)
# Out:
# Day la con ga
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
nr_to_predict = 57
pred = model.predict(X_test_features[nr_to_predict].reshape(1, 41,))
if (y_test[nr_to_predict] == 0):
    print ("Day la con meo")
if (y_test[nr_to_predict] == 1):
    print ("Day la con cho")
if (y_test[nr_to_predict] == 2):
  print ("Day la con chim")
if (y_test[nr_to_predict] == 3):
  print ("Day la con ga")
if (y_test[nr_to_predict] == 4):
    print ("Day la con ech")
if (y_test[nr_to_predict] == 5):
    print ("Day la con bo")
if (y_test[nr_to_predict] == 6):
    print ("Day la con su tu")
if (y_test[nr_to_predict] == 7):
    print ("Day la con ngua")
if (y_test[nr_to_predict] == 8):
    print ("Day la con heo")
if (y_test[nr_to_predict] == 9):
    print ("Day la con cuu")
plt.plot(X_test_features[nr_to_predict])
ipd.Audio(X_test[nr_to_predict],  rate=wav_rate)
# Out:
# Day la con bo
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
nr_to_predict = 2
pred = model.predict(X_test_features[nr_to_predict].reshape(1, 41,))
if (y_test[nr_to_predict] == 0):
    print ("Day la con meo")
if (y_test[nr_to_predict] == 1):
    print ("Day la con cho")
if (y_test[nr_to_predict] == 2):
  print ("Day la con chim")
if (y_test[nr_to_predict] == 3):
  print ("Day la con ga")
if (y_test[nr_to_predict] == 4):
    print ("Day la con ech")
if (y_test[nr_to_predict] == 5):
    print ("Day la con bo")
if (y_test[nr_to_predict] == 6):
    print ("Day la con su tu")
if (y_test[nr_to_predict] == 7):
    print ("Day la con ngua")
if (y_test[nr_to_predict] == 8):
    print ("Day la con heo")
if (y_test[nr_to_predict] == 9):
    print ("Day la con cuu")
plt.plot(X_test_features[nr_to_predict])
ipd.Audio(X_test[nr_to_predict],  rate=wav_rate)
# Out:
# Day la con cuu
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
nr_to_predict = 16
pred = model.predict(X_test_features[nr_to_predict].reshape(1, 41,))
if (y_test[nr_to_predict] == 0):
    print ("Day la con meo")
if (y_test[nr_to_predict] == 1):
    print ("Day la con cho")
if (y_test[nr_to_predict] == 2):
  print ("Day la con chim")
if (y_test[nr_to_predict] == 3):
  print ("Day la con ga")
if (y_test[nr_to_predict] == 4):
    print ("Day la con ech")
if (y_test[nr_to_predict] == 5):
    print ("Day la con bo")
if (y_test[nr_to_predict] == 6):
    print ("Day la con su tu")
if (y_test[nr_to_predict] == 7):
    print ("Day la con ngua")
if (y_test[nr_to_predict] == 8):
    print ("Day la con heo")
if (y_test[nr_to_predict] == 9):
    print ("Day la con cuu")
plt.plot(X_test_features[nr_to_predict])
ipd.Audio(X_test[nr_to_predict],  rate=wav_rate)
# Out:
# Day la con heo
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
nr_to_predict = 17
pred = model.predict(X_test_features[nr_to_predict].reshape(1, 41,))
if (y_test[nr_to_predict] == 0):
    print ("Day la con meo")
if (y_test[nr_to_predict] == 1):
    print ("Day la con cho")
if (y_test[nr_to_predict] == 2):
  print ("Day la con chim")
if (y_test[nr_to_predict] == 3):
  print ("Day la con ga")
if (y_test[nr_to_predict] == 4):
    print ("Day la con ech")
if (y_test[nr_to_predict] == 5):
    print ("Day la con bo")
if (y_test[nr_to_predict] == 6):
    print ("Day la con su tu")
if (y_test[nr_to_predict] == 7):
    print ("Day la con ngua")
if (y_test[nr_to_predict] == 8):
    print ("Day la con heo")
if (y_test[nr_to_predict] == 9):
    print ("Day la con cuu")
plt.plot(X_test_features[nr_to_predict])
ipd.Audio(X_test[nr_to_predict],  rate=wav_rate)
# Out:
# Day la con cho
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
